# %%
renv::activate()

# %%
library(dplyr)
library(ggplot2)
library(reshape2)

options(warn=-1, repr.plot.width=16, repr.plot.height=12)
suppressMessages(warning('testit'))
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ## Subset Data to only the Precent positive of immune cells

# %%
## child data
child <- read.table('data/child_forest_imputed.tsv',
                    sep = '\t', header = TRUE, stringsAsFactors=FALSE)
child.p <- dplyr::select(child,
                         Percent.CD4.T.cells:Percent.DRpositive.CD38negative.of.CD8.Tem.cells
)

## Adult data
adult <- read.table('data/adult_forest_imputed.tsv',
                    sep = '\t', header = TRUE, stringsAsFactors=FALSE)
adult.p <- dplyr::select(adult,
                         Percent.CD4.T.cells:Percent.DRpositive.CD38negative.of.CD8.Tem.cells
)

# %% [markdown]
# ## Wilcoxon test

# %%
## Wilcoxon test child
wct_child <- c()
for (i in 1:ncol(child.p)){
        patient_group <- split(x = child.p[[i]], f= child$Patient.group)
        wct <- wilcox.test(x = patient_group[[1]], y = patient_group[[2]], 
                           alternative = 'two.sided', paired = F, exact = T)
        wct_child <- c(wct_child, wct$p.value)  
}
names(wct_child) <- colnames(child.p)

## Wilcoxon test Adult
wct_adult <- c()
for (i in 1:ncol(adult.p)){
        patient_group <- split(x = adult.p[[i]], f= adult$Patient.group)
        wct <- wilcox.test(x = patient_group[[1]], y = patient_group[[2]], 
                           alternative = 'two.sided', paired = F, exact = T)
        wct_adult <- c(wct_adult, wct$p.value)  
}
names(wct_adult) <- colnames(adult.p)

# %% [markdown]
# Saving results

# %%
## child
wct_child_df <- data.frame('variable'=names(wct_child),
                    'p_val'=wct_child,
                    stringsAsFactors = FALSE)

## Saving results
wct_child_df %>% filter(p_val < 0.05) %>% write.table('data/child_wilcoxon_test.tsv')

## adult
wct_adult_df <- data.frame('variable'=names(wct_adult),
                    'p_val'=wct_adult,
                    stringsAsFactors = FALSE)

## Saving results
wct_adult_df %>% filter(p_val < 0.05) %>% write.table('data/adult_wilcoxon_test.tsv')

# %% [markdown]
# ## Top 9 differentially distributed variables in obese vs eutrofic childrens

# %%
child_confident_vars <- wct_child_df %>% 
                     filter(p_val < 0.05) %>% 
                       dplyr::select(variable) %>% 
                         unlist

child[, colnames(child) %in% c('Patient.group', child_confident_vars[1:9])] %>% 
          melt %>% ggplot(aes(x=Patient.group, y=log(value))) +
             geom_boxplot(aes(fill=Patient.group)) + 
             geom_point() +
             facet_wrap(~variable, ncol = 3) +
             theme_light()
# Out:
# Using Patient.group as id variables
# plot without title

# %% [markdown]
# ## Prepare data for plotting

# %%
# Merge child and adults wilcox
wct_df = wct_child_df %>% left_join(wct_adult_df, by='variable', suffix = c('.child', '.adult'))

# Get the variance

melt.list

# %%
colnames(child)
# Out:
#   [1] "Age"
#   [2] "Gender"
#   [3] "Tanner.p"
#   [4] "Tanner.g"
#   [5] "Weight.Kg"
#   [6] "Height.cm"
#   [7] "Neck.circumference.cm"
#   [8] "Waist.circumference.cm"
#   [9] "Hip.circumference.cm"
#  [10] "Waist.to.height.ratio"
#  [11] "Lean.body.mass.Kg"
#  [12] "mass.body.fat.Kg"
#  [13] "Soft.lean.mass.Kg"
#  [14] "Protein.Kg"
#  [15] "Total.body.water.Kg"
#  [16] "Percent.body.fat"
#  [17] "Body.mass.index"
#  [18] "Fatness"
#  [19] "Visceral.fat.area.cm2"
#  [20] "Waist.hip.ratio"
#  [21] "Body.fat.Kg"
#  [22] "Left.arm.mass.body.fat.Kg"
#  [23] "Left.arm..soft.lean.mass.Kg"
#  [24] "Right.arm.mass.body.fat.Kg"
#  [25] "Right.arm.soft.lean.mass.Kg"
#  [26] "Trunk.mass.body.fat.Kg"
#  [27] "Trunk.soft.lean.mass.Kg"
#  [28] "Left.leg.mass.body.fat.Kg"
#  [29] "Left.leg.soft.lean.mass.Kg"
#  [30] "Right.leg.mass.body.fat.Kg"
#  [31] "Right.leg.soft.lean.mass.Kg"
#  [32] "Intima.media.thickness"
#  [33] "Systolic.blood.pressure"
#  [34] "Diastolic.blood.pressure"
#  [35] "BASALDIL.MAX"
#  [36] "P.ISQ.DIL.MAX"
#  [37] "DIL.FLUJOBRA"
#  [38] "Hepatic.steatosis"
#  [39] "Vsiceral.fat"
#  [40] "Physical.activity"
#  [41] "Leucocytes"
#  [42] "Neutrophils"
#  [43] "Lymphocytes"
#  [44] "Monocytes"
#  [45] "Band.neutrophils"
#  [46] "Eosinophils"
#  [47] "Basophils"
#  [48] "Hemoglobin.g.dL"
#  [49] "Hematocrit"
#  [50] "Mean.Corpuscular.Volume.fL"
#  [51] "Mean.cell.hemoglobin.pg"
#  [52] "Red.blood.cell.distribution.width"
#  [53] "Platelets"
#  [54] "Fasting.glucose.mg.dL"
#  [55] "Uric.acid.mg.dL"
#  [56] "Total.cholesterol.mg.dL"
#  [57] "Triglycerides.mg.dL"
#  [58] "HDL.cholesterolmg.dL"
#  [59] "LDL.cholesterol.mg.dL"
#  [60] "ALT.U.L"
#  [61] "AST.32U.L"
#  [62] "Glucose.30.minutes.mg.dL"
#  [63] "Glucose.60.minutes.mg.dL"
#  [64] "Glucose.90.minutes.mg.dL"
#  [65] "Glucose.120.minutes.mg.dL"
#  [66] "Basal.insulin"
#  [67] "Insulin.30.minutes"
#  [68] "Insulin.60.minutes"
#  [69] "Insulin.90.minutes"
#  [70] "Insulin.120.minutes"
#  [71] "HOMA.IR"
#  [72] "MATSUDA.index"
#  [73] "Microangiopathic.hemolysis"
#  [74] "Endocan"
#  [75] "LPS.pg.mL"
#  [76] "Percent.CD4.T.cells"
#  [77] "Percent.CD8.T.cells"
#  [78] "CD4.CD8.ratio"
#  [79] "Percent.CD4.Tcm.cells"
#  [80] "Percent.CD4.Tem.cells"
#  [81] "Percent.CD4.Tn.cells"
#  [82] "Percent.CD4.Temra.cells"
#  [83] "Percent.CD8.Tcm.cells"
#  [84] "Percent.CD8.Tem.cells"
#  [85] "Percent.CD8.Tn.cells"
#  [86] "Percent.CD8.Temra.cells"
#  [87] "Calculated.CD4.lymphocyte.count"
#  [88] "Calculated.CD8.T.cell.count"
#  [89] "Calculated.CD4.Tcm.cell.count"
#  [90] "Calculated.CD4.Tem.cell.count"
#  [91] "Calculated.CD4.Tn.cell.count"
#  [92] "Calculated.CD4.Temra.cell..count"
#  [93] "Calculated.CD8.Tcm.cell.count"
#  [94] "Calculated.CD8.Tem..count"
#  [95] "Calculated.CD8.Tn.count"
#  [96] "Calculated.CD8.Temra.count"
#  [97] "Percent.CD38positive.of.CD4.T.cells"
#  [98] "CD38MFI.of.CD38positive.CD4.T.cells"
#  [99] "Percent.DRnegative.CD38positive.of.CD4.T.cells"
# [100] "CD38MFI.of.DRnegative.CD38positive.CD4.T.cells"
# [101] "Percent.DRpositive.CD38positive.CD4.T.cells"
# [102] "CD38MFI.of.DRpositive.CD38positive.CD4.T.cells"
# [103] "Percent.DRpositive.CD38negative.CD4.T.cells"
# [104] "Percent.CD38positive.of.CD4.Temra.cells"
# [105] "CD38MFI.of.CD38positive.CD4.Temra.cells"
# [106] "Percent.DRnegative.CD38positive.of.CD4.Temra.cells"
# [107] "CD38MFI.of.DRnegative.CD38positive.CD4.Temra.cells"
# [108] "Percent.DRpositive.CD38positive.of.CD4.Temra.cells"
# [109] "CD38MFI.of.DRpositive.CD38positive.CD4.Temra.cells"
# [110] "Percent.DRpositive.CD38negative.of.CD4.Temra.cells"
# [111] "Percent.CD38positive.of.CD4.Tn.cells"
# [112] "CD38MFI.of.CD38positive.CD4.Tn.cells"
# [113] "Percent.DRnegative.CD38positive.CD4.Tn.cells"
# [114] "CD38MFI.of.DRnegative.CD38positive.CD4.Tn.cells"
# [115] "Percent.DRpositive.CD38positive.CD4.Tn.cells"
# [116] "CD38MFI.of.DRpositive.CD38positive.CD4.Tn.cells"
# [117] "Percent.DRpositive.CD38negative.CD4.Tn.cells"
# [118] "Percent.CD38positive.CD4.Tcm.cells"
# [119] "CD38MFI.of.CD38positive.CD4.Tcm.cells"
# [120] "Percent.DRnegative.CD38positive.CD4.Tcm.cells"
# [121] "CD38MFI.of.DRnegative.CD38positive.CD4.Tcm.cells"
# [122] "Percent.DRpositive.CD38positive.of.Tcm.CD4"
# [123] "CD38MFI.of.DRpositive.CD38positive.CD4.Tcm.cells"
# [124] "Percent.DRpositive.CD38negative.of.CD4.Tcm.cells"
# [125] "Percent.CD38positive.of.CD4.Tem.cells"
# [126] "CD38MFI.of.CD38positive.CD4.Tem.cells"
# [127] "Percent.DRnegative.CD38positive.of.CD4.Tem.cells"
# [128] "CD38MFI.of.DRnegative.CD38positive.CD4.Tem.cells"
# [129] "Percent.DRpositive.CD38positive.of.CD4.Tem.cells"
# [130] "Percent.DRpositive.CD38negative.CD4.Tem.cells"
# [131] "Percent.CD38positive.of.CD8.T.cells"
# [132] "CD38MFI.of.CD38positive.CD8.T.cells"
# [133] "Percent.DRnegative.CD38Positive.of.CD8.T.cells"
# [134] "CD38MFI.of.DRnegative.CD38positive.CD8.T.cells"
# [135] "Percent.DRpositive.CD38positive.of.CD8.T.cells"
# [136] "CD38MFI.of.DRpositive.CD38positive.CD8.T.cells"
# [137] "Percent.DRpositive.CD38negative.of.CD8.T.cells"
# [138] "Percent.CD38positive.of.CD8.Temra.cells"
# [139] "CD38MFI.of.CD38positive.CD8.Temra.cells"
# [140] "Percent.DRnegative.CD38positive.CD8.Temra.cells"
# [141] "CD38MFI.of.DRnegative.CD38positive.CD8.Temra.cells"
# [142] "Percent.DRpositive.CD38positive.of.CD8.Temra.cells"
# [143] "Percent.DRpositive.CD38negative.of.CD8.Temra.cells"
# [144] "Percent.CD38positive.of.CD8.Tn.cells"
# [145] "CD38MFI.of.CD38.CD8.Tn.cells"
# [146] "Percent.DRnegative.CD38positive.of.CD8.Tn.cells"
# [147] "CD38MFI.of.DRnegative.CD38positive.CD8.Tn.cells"
# [148] "Percent.DRpositive.CD38positive.CD8.Tn.cells"
# [149] "CD38MFI.of.DRpositive.CD38positive.CD8.Tn.cells"
# [150] "Percent.DRpositive.CD38negative.of.CD8.Tn.cells"
# [151] "Percent.CD38positive.of.CD8.Tcm.cells"
# [152] "CD38MFI.of.CD38positive.CD8.Tcm.cells"
# [153] "Percent.DRnegative.CD38positive.of.CD8.Tcm.cells"
# [154] "CD38MFI.of.DRnegative.CD38positive.of.CD8.Tcm.cells"
# [155] "Percent.DRpositive.CD38positive.of.CD8.Tcm.cells"
# [156] "Percent.DRpositive.CD38negativa.of.CD8.Tcm.cells"
# [157] "Percent.CD38positive.of.CD8.Tem.cells"
# [158] "CD38MFI.of.CD38positive.CD8.Tem.cells"
# [159] "Percent.DRnegative.CD38positive.of.CD8.Tem.cells"
# [160] "CD38MFI.of.DRnegative.CD38positive.CD8.Tem.cells"
# [161] "Percent.DRpositive.CD38positive.of.CD8.Tem.cells"
# [162] "CD38MFI.of.DRpositive.CD38positive.CD8.Tem.cells"
# [163] "Percent.DRpositive.CD38negative.of.CD8.Tem.cells"
# [164] "Patient.group"
